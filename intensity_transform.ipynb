# %%
import cv2
import numpy as np
import math
import copy
from matplotlib import pyplot as plt
import matplotlib.image as mpimg
from pylab import *

# %%
img = cv2.imread("tower.jpg", 0)

# %%
row,col=(img.shape)

# %%
negative=np.zeros((row,col))

# %%
for i in range (row):
    for j in range (col):
        negative[i][j]=255-img[i][j]

# %%
plt.imshow(negative, cmap = 'gray', interpolation = 'bicubic')

# %%
plt.show()

# %%
plt.imshow(img, cmap = 'gray', interpolation = 'bicubic')

# %%
plt.show()

# %%
gamma=np.zeros((row,col))

# %%
g=0.1

# %%
for i in range (row):
    for j in range (col):
        gamma[i][j]=50*pow(img[i][j],g)

# %%
plt.imshow(gamma, cmap = 'gray', interpolation = 'bicubic')

# %%
plt.show()

# %%
g=0.05

# %%
for i in range (row):
    for j in range (col):
        negative[i][j]=255-img[i][j]

# %%
plt.imshow(gamma, cmap = 'gray', interpolation = 'bicubic')

# %%
plt.show()

# %%
log=np.zeros((row,col))
for i in range (row):
    for j in range (col):
        log[i][j]=150*log10(1+img[i][j])

# %%
fig, a = subplots(1,4, figsize=(20, 20))
a[0].imshow(img, cmap = 'gray', interpolation = 'bicubic')
a[0].axis('on')
a[0].set_title('Original', fontsize=20)
a[1].imshow(negative,  cmap = 'gray', interpolation = 'bicubic')
a[1].axis('on')
a[1].set_title('Negative', fontsize=20)
a[2].imshow(log,  cmap = 'gray', interpolation = 'bicubic')
a[2].axis('on')
a[2].set_title('Log', fontsize=20)
a[3].imshow(gamma,  cmap = 'gray', interpolation = 'bicubic')
a[3].axis('on')
a[3].set_title('Gamma', fontsize=20)

fig, a1 = subplots(1,4, figsize=(20, 20))
a1[0].imshow(img)
a1[0].axis('on')
a1[0].set_title('Original', fontsize=20)
a1[1].imshow(negative)
a1[1].axis('on')
a1[1].set_title('Negative', fontsize=20)
a1[2].imshow(log)
a1[2].axis('on')
a1[2].set_title('Log', fontsize=20)
a1[3].imshow(gamma)
a1[3].axis('on')
a1[3].set_title('Gamma', fontsize=20)

# %%
plt.show()
