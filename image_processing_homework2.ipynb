# %%
import cv2
import numpy as np
import math
import copy
from matplotlib import pyplot as plt

# %%
img = cv2.imread("tower.jpg", 0)

# %%
plt.imshow(img, cmap = 'gray', interpolation = 'bicubic')

# %%
plt.show()

# %%
plt.xticks([]), plt.yticks([])
# Out:
# (([], <a list of 0 Text xticklabel objects>),
#  ([], <a list of 0 Text yticklabel objects>))

# %%
plt.plot([200,300,400],[100,200,300],'c', linewidth=5)

# %%
plt.show()

# %%
plt.imshow(img, cmap = 'gray', interpolation = 'bicubic')

# %%
plt.xticks([]), plt.yticks([])
# Out:
# (([], <a list of 0 Text xticklabel objects>),
#  ([], <a list of 0 Text yticklabel objects>))

# %%
plt.plot([200,300,400],[100,200,300],'c', linewidth=5)

# %%
plt.show()

# %%
cv2.imwrite("image_edit_save.jpg",img);

# %%
img = cv2.imread("tower.jpg")

# %%
plt.imshow(img, cmap = 'gray', interpolation = 'bicubic')

# %%
print(img.shape)
# Out:
# (400L, 760L, 3L)

# %%
color = np.array([[0 for color in range(3)] for i in range(256)])

# %%
print(color.shape)
# Out:
# (256L, 3L)

# %%
Negative = np.zeros((img.shape[0],img.shape[0],3), 'uint8')

# %%
for i in range(0,Negative.shape[0]):
    for j in range(0,Negative.shape[1]):
        Negative[i,j,0] = 255 - img[i,j,0]
        color[Negative[i,j,0]][0] +=1
        Negative[i,j,1] = 255 - img[i,j,1]
        color[Negative[i,j,1]][1] +=1
        Negative[i,j,2] = 255 - img[i,j,2]
        color[Negative[i,j,2]][2] +=1

# %%
for i in range(color.shape[0]):
   print(i,color[i])
# Out:
# (0, array([ 0,  0, 21]))
# (1, array([ 0,  1, 19]))
# (2, array([ 0,  0, 17]))
# (3, array([ 0,  2, 17]))
# (4, array([ 0,  1, 20]))
# (5, array([ 0,  0, 10]))
# (6, array([ 0,  0, 31]))
# (7, array([ 0,  1, 42]))
# (8, array([ 0,  0, 41]))
# (9, array([ 0,  5, 52]))
# (10, array([ 0,  1, 58]))
# (11, array([ 0,  3, 60]))
# (12, array([ 0,  2, 62]))
# (13, array([ 1,  2, 61]))
# (14, array([ 0,  1, 72]))
# (15, array([ 3,  1, 88]))
# (16, array([ 0,  1, 87]))
# (17, array([ 1,  2, 89]))
# (18, array([  0,   3, 107]))
# (19, array([  0,   3, 112]))
# (20, array([  0,   1, 115]))
# (21, array([  1,   3, 131]))
# (22, array([  1,   3, 123]))
# (23, array([  1,   8, 139]))
# (24, array([  1,   5, 125]))
# (25, array([  1,   6, 163]))
# (26, array([  0,  14, 143]))
# (27, array([  2,   8, 169]))
# (28, array([  2,  14, 181]))
# (29, array([  1,  15, 170]))
# (30, array([  2,  18, 218]))
# (31, array([  1,  11, 242]))
# (32, array([  1,  14, 265]))
# (33, array([  2,  19, 263]))
# (34, array([  1,  25, 335]))
# (35, array([  2,  28, 345]))
# (36, array([  3,  29, 380]))
# (37, array([  3,  34, 457]))
# (38, array([  5,  43, 437]))
# (39, array([  2,  52, 434]))
# (40, array([  1,  50, 458]))
# (41, array([  5,  49, 420]))
# (42, array([  2,  56, 382]))
# (43, array([  4,  61, 432]))
# (44, array([  6,  58, 401]))
# (45, array([  4,  68, 360]))
# (46, array([  7,  76, 316]))
# (47, array([  5,  71, 325]))
# (48, array([  5,  74, 312]))
# (49, array([  9,  91, 312]))
# (50, array([  8,  89, 270]))
# (51, array([  9,  92, 292]))
# (52, array([  6,  85, 288]))
# (53, array([ 13, 103, 278]))
# (54, array([ 15, 121, 260]))
# (55, array([ 12, 119, 235]))
# (56, array([ 17, 113, 244]))
# (57, array([ 13, 118, 223]))
# (58, array([ 24, 142, 227]))
# (59, array([ 24, 147, 189]))
# (60, array([ 23, 174, 215]))
# (61, array([ 28, 176, 234]))
# (62, array([ 21, 192, 205]))
# (63, array([ 29, 189, 203]))
# (64, array([ 34, 187, 191]))
# (65, array([ 34, 196, 197]))
# (66, array([ 42, 234, 166]))
# (67, array([ 30, 212, 165]))
# (68, array([ 34, 226, 154]))
# (69, array([ 39, 228, 140]))
# (70, array([ 47, 236, 144]))
# (71, array([ 41, 245, 183]))
# (72, array([ 56, 249, 160]))
# (73, array([ 66, 257, 168]))
# (74, array([ 55, 253, 185]))
# (75, array([ 70, 277, 173]))
# (76, array([ 65, 219, 158]))
# (77, array([ 61, 236, 177]))
# (78, array([ 70, 236, 176]))
# (79, array([ 80, 255, 171]))
# (80, array([ 77, 238, 163]))
# (81, array([ 65, 229, 155]))
# (82, array([105, 237, 163]))
# (83, array([ 81, 231, 143]))
# (84, array([ 79, 229, 150]))
# (85, array([ 99, 213, 150]))
# (86, array([ 88, 226, 136]))
# (87, array([108, 224, 139]))
# (88, array([111, 248, 165]))
# (89, array([105, 237, 164]))
# (90, array([101, 246, 144]))
# (91, array([114, 243, 125]))
# (92, array([109, 229, 130]))
# (93, array([124, 221, 153]))
# (94, array([132, 206, 148]))
# (95, array([142, 223, 156]))
# (96, array([183, 217, 175]))
# (97, array([192, 200, 183]))
# (98, array([239, 207, 179]))
# (99, array([280, 192, 166]))
# (100, array([333, 182, 187]))
# (101, array([357, 171, 166]))
# (102, array([383, 179, 200]))
# (103, array([415, 179, 178]))
# (104, array([505, 190, 233]))
# (105, array([566, 179, 226]))
# (106, array([657, 164, 239]))
# (107, array([805, 151, 258]))
# (108, array([918, 154, 255]))
# (109, array([1037,  174,  277]))
# (110, array([1201,  141,  254]))
# (111, array([1352,  160,  247]))
# (112, array([1503,  172,  269]))
# (113, array([1632,  169,  235]))
# (114, array([1734,  201,  225]))
# (115, array([1789,  190,  276]))
# (116, array([1725,  147,  204]))
# (117, array([1987,  144,  195]))
# (118, array([2041,  140,  199]))
# (119, array([1767,  154,  184]))
# (120, array([1842,  146,  179]))
# (121, array([2018,  151,  191]))
# (122, array([2037,  138,  188]))
# (123, array([1964,  140,  178]))
# (124, array([1950,  125,  150]))
# (125, array([2152,  161,  170]))
# (126, array([2109,  176,  124]))
# (127, array([2070,  140,  113]))
# (128, array([1841,  145,  121]))
# (129, array([1811,  142,  109]))
# (130, array([1785,  136,  103]))
# (131, array([1769,  146,   82]))
# (132, array([1571,  140,   84]))
# (133, array([1410,  138,   94]))
# (134, array([1275,  145,   85]))
# (135, array([1250,  145,   58]))
# (136, array([1210,  128,   90]))
# (137, array([1080,  145,   63]))
# (138, array([887, 157,  58]))
# (139, array([862, 174,  73]))
# (140, array([708, 167,  72]))
# (141, array([516, 201,  79]))
# (142, array([408, 199,  52]))
# (143, array([293, 230,  72]))
# (144, array([211, 235,  65]))
# (145, array([183, 244,  70]))
# (146, array([175, 274,  41]))
# (147, array([161, 269,  68]))
# (148, array([170, 261,  68]))
# (149, array([194, 246,  62]))
# (150, array([195, 291,  45]))
# (151, array([171, 281,  51]))
# (152, array([177, 384,  48]))
# (153, array([181, 412,  44]))
# (154, array([152, 487,  57]))
# (155, array([158, 563,  55]))
# (156, array([191, 591,  61]))
# (157, array([185, 796,  62]))
# (158, array([148, 918,  66]))
# (159, array([ 167, 1091,   57]))
# (160, array([ 176, 1340,   61]))
# (161, array([ 151, 1460,   52]))
# (162, array([ 146, 1668,   49]))
# (163, array([ 177, 1944,   68]))
# (164, array([ 162, 2208,   48]))
# (165, array([ 152, 2392,   50]))
# (166, array([ 154, 2564,   59]))
# (167, array([ 144, 2930,   43]))
# (168, array([ 169, 3128,   52]))
# (169, array([ 161, 3364,   50]))
# (170, array([ 157, 3396,   44]))
# (171, array([ 140, 2975,   52]))
# (172, array([ 146, 2812,   58]))
# (173, array([ 162, 2612,   52]))
# (174, array([ 157, 2551,   48]))
# (175, array([ 166, 2380,   57]))
# (176, array([ 167, 2202,   53]))
# (177, array([ 146, 1954,   52]))
# (178, array([ 130, 1703,   43]))
# (179, array([ 153, 1397,   50]))
# (180, array([ 140, 1203,   34]))
# (181, array([145, 829,  59]))
# (182, array([148, 694,  48]))
# (183, array([155, 692,  52]))
# (184, array([131, 582,  56]))
# (185, array([151, 438,  62]))
# (186, array([145, 286,  49]))
# (187, array([138, 142,  62]))
# (188, array([156, 123,  61]))
# (189, array([158,  88,  53]))
# (190, array([121, 101,  61]))
# (191, array([170,  75,  65]))
# (192, array([162,  74,  66]))
# (193, array([162,  75,  68]))
# (194, array([168,  76,  66]))
# (195, array([133,  88,  66]))
# (196, array([175,  78,  64]))
# (197, array([145,  67,  74]))
# (198, array([180,  83,  77]))
# (199, array([159,  89,  75]))
# (200, array([209,  86,  78]))
# (201, array([188,  87, 109]))
# (202, array([227,  63, 115]))
# (203, array([206,  86, 133]))
# (204, array([230,  63, 175]))
# (205, array([210,  95, 192]))
# (206, array([226,  61, 236]))
# (207, array([210,  76, 292]))
# (208, array([238,  79, 357]))
# (209, array([230,  86, 486]))
# (210, array([233,  90, 639]))
# (211, array([239,  83, 813]))
# (212, array([223,  81, 986]))
# (213, array([215,  80, 953]))
# (214, array([258,  84, 950]))
# (215, array([ 254,   86, 1062]))
# (216, array([ 217,   92, 1320]))
# (217, array([ 239,   95, 1347]))
# (218, array([ 236,   90, 1469]))
# (219, array([ 214,   85, 1654]))
# (220, array([ 234,   96, 1747]))
# (221, array([ 214,  102, 1932]))
# (222, array([ 188,   99, 2034]))
# (223, array([ 227,  117, 2328]))
# (224, array([ 199,  119, 2411]))
# (225, array([ 189,  139, 2550]))
# (226, array([ 206,  131, 2740]))
# (227, array([ 177,  149, 2721]))
# (228, array([ 181,  162, 3043]))
# (229, array([ 144,  164, 3339]))
# (230, array([ 154,  184, 3553]))
# (231, array([ 153,  236, 3626]))
# (232, array([ 162,  257, 3728]))
# (233, array([ 178,  337, 3771]))
# (234, array([ 164,  384, 3800]))
# (235, array([ 155,  470, 3751]))
# (236, array([ 172,  642, 3724]))
# (237, array([ 169,  752, 3503]))
# (238, array([ 180,  872, 3408]))
# (239, array([ 187, 1101, 3257]))
# (240, array([ 207, 1350, 3080]))
# (241, array([ 204, 1626, 2861]))
# (242, array([ 252, 1837, 2586]))
# (243, array([ 279, 2124, 2533]))
# (244, array([ 367, 2491, 2373]))
# (245, array([ 443, 2840, 2207]))
# (246, array([ 528, 3229, 1928]))
# (247, array([ 850, 3717, 1970]))
# (248, array([1242, 3998, 1915]))
# (249, array([2068, 4132, 2152]))
# (250, array([3285, 4158, 2160]))
# (251, array([5097, 4048, 2077]))
# (252, array([7701, 4003, 2012]))
# (253, array([10382,  4056,  2070]))
# (254, array([11848,  5080,  2761]))
# (255, array([36925, 24753, 21932]))

# %%
valmax1 = 0
valmax2 = 0
valmax3 = 0

# %%
for i in range(color.shape[0]):
    if valmax1 < color[i][0]:
        valmax1 = color[i][0]
    if valmax2 < color[i][1]:
        valmax2 = color[i][1]
    if valmax3 < color[i][2]:
        valmax3 = color[i][2]

# %%
plt.imshow(Negative, cmap = 'gray', interpolation = 'bicubic')

# %%
plt.show()

# %%
log = np.zeros((img.shape[0],img.shape[0],3), 'uint8')

# %%
c = 1.5
for i in range(0,log.shape[0]):
    for j in range(0,log.shape[1]):
        if (c*math.log(1+img[i,j,0],2)) < 0:
            log[i,j,0] = 0
        else:
            log[i,j,0] = np.int(c*math.log(1+img[i,j,0],2))
        if (c*math.log(1+img[i,j,1],2)) < 0:
             log[i,j,1] = 0
        else:
            log[i,j,1] = np.int(c*math.log(1+img[i,j,1],2))
        if (c*math.log(1+img[i,j,2],2)) < 0:
             log[i,j,2] = 0
        else:
            log[i,j,2] = np.int(c*math.log(1+img[i,j,2],2))

# %%
cv2.imshow("log", log)

# %%
plt.imshow(log, cmap = 'gray', interpolation = 'bicubic')

# %%
plt.show()

# %%
cv2.imshow("Negative", Negative)

# %%
plt.imshow(Negative, cmap = 'gray', interpolation = 'bicubic')

# %%
plt.show()

# %%
gamma = img

# %%
for i in range(0,log.shape[0]):
    for j in range(0,log.shape[1]):
        gamma[i,j,0] = np.int(math.gamma(1+img[i,j,0]))
        gamma[i,j,1] = np.int(math.gamma(1+img[i,j,1]))
        gamma[i,j,2] = np.int(math.gamma(1+img[i,j,2]))
# Out:
# ---------------------------------------------------------------------------
# OverflowError                             Traceback (most recent call last)
# <ipython-input-34-9685e1e14ce9> in <module>()
#       1 for i in range(0,log.shape[0]):
#       2     for j in range(0,log.shape[1]):
# ----> 3         gamma[i,j,0] = np.int(math.gamma(1+img[i,j,0]))
#       4         gamma[i,j,1] = np.int(math.gamma(1+img[i,j,1]))
#       5         gamma[i,j,2] = np.int(math.gamma(1+img[i,j,2]))
#
# OverflowError: Python int too large to convert to C long

# %%
plt.imshow(gamma, cmap = 'gray', interpolation = 'bicubic')

# %%
plt.show()

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt
img = cv2.imread("tower.jpg")

kernal = np.array([[1/9,1/9,1/9],[1/9,1/9,0/9],[1/9,1/9,1/9]])

average = np.zeros((img.shape[0],img.shape[1],3), 'uint8')

print(average.shape)
cv2.imshow("org",img)

# %%
plt.imshow(average, cmap = 'gray', interpolation = 'bicubic')

# %%
plt.show()

# %%
for i in range(1,average.shape[0]-1):
    for j in range(1,average.shape[1]-1):
        for k in range(0,2):
            for l in range(0,2):
                average[i,j,0] += int(img[i,j,0] * kernal[k][l])
                average[i,j,1] += int(img[i,j,1] * kernal[k][l])
                average[i,j,2] += int(img[i,j,2] * kernal[k][l])

# %%
cv2.imshow("Convolution_average",average)

# %%
plt.imshow(Convolution_average, cmap = 'gray', interpolation = 'bicubic')

# %%
plt.show()

# %%
kernal_laplacian = np.array([[1,1,1],[1,-8,1],[1,1,1]])
kernal_laplacian2 = np.array([[0,1,0],[1,-4,1],[0,1,0]])
laplacian  = np.zeros((img.shape[0],img.shape[1],3), 'uint8')

# %%
print(average.shape)

# %%
for i in range(1,laplacian.shape[0]-1):
    for j in range(1,laplacian.shape[1]-1):
        for k in range(0,2):
            for l in range(0,2):
                laplacian[i,j,0] += int(img[i+k-1,j+l-1,0] * kernal_laplacian[k][l])
                laplacian[i,j,1] += int(img[i+k-1,j+l-1,1] * kernal_laplacian[k][l])
                laplacian[i,j,2] += int(img[i+k-1,j+l-1,2] * kernal_laplacian[k][l])

# %%
plt.imshow(Convolution_laplacian, cmap = 'gray', interpolation = 'bicubic')

# %%
plt.show()

# %%
def bubble_sort(random_list):    
    for start_index in range( len(random_list)-1 ):
        for index in range( 1, len(random_list) - start_index ):
            if random_list[index-1] > random_list[index]:
                temp = random_list[index-1]
                random_list[index-1] = random_list[index]
                random_list[index] = temp
                
    return random_list[int(len(random_list)/2)]

# %%
median  = np.zeros((img.shape[0],img.shape[1],3), 'uint8')

median_array = np.zeros((3,9), 'uint8')

# %%
for i in range(1,median.shape[0]-1):
    for j in range(1,median.shape[1]-1):
        cnt = 0
        for k in range(0,3):
            for l in range(0,3):
                median_array[0,cnt]=img[i+k-1,j+l-1,0]
                median_array[1,cnt]=img[i+k-1,j+l-1,1]
                median_array[2,cnt]=img[i+k-1,j+l-1,2]
                cnt = cnt+1
                      
        median[i,j,0] = bubble_sort(median_array[0])
        median[i,j,1] = bubble_sort(median_array[1])
        median[i,j,2] = bubble_sort(median_array[2])

# %%
cv2.imshow("Convolution_median",median)

# %%
cv2.waitKey()
cv2.destroyAllWindows()

# %%
def bubble_sort_Max(random_list):    
    for start_index in range( len(random_list)-1 ):
        for index in range( 1, len(random_list) - start_index ):
            if random_list[index-1] > random_list[index]:
                temp = random_list[index-1]
                random_list[index-1] = random_list[index]
                random_list[index] = temp
                
    return random_list[len(random_list)-2]

# %%
Max_img  = np.zeros((img.shape[0],img.shape[1],3), 'uint8')

Max_array = np.zeros((3,9), 'uint8')

# %%
plt.imshow(actual, cmap = 'gray', interpolation = 'bicubic')

# %%
plt.show()

# %%
cnt = 0

# %%
for i in range(1,Max_img.shape[0]-1):
    for j in range(1,Max_img.shape[1]-1):
        cnt = 0
        for k in range(0,3):
            for l in range(0,3):
                Max_array[0,cnt]=img[i+k-1,j+l-1,0]
                Max_array[1,cnt]=img[i+k-1,j+l-1,1]
                Max_array[2,cnt]=img[i+k-1,j+l-1,2]
                cnt = cnt+1
                      
        Max_img[i,j,0] = bubble_sort_Max(Max_array[0])
        Max_img[i,j,1] = bubble_sort_Max(Max_array[1])
        Max_img[i,j,2] = bubble_sort_Max(Max_array[2])

# %%
plt.imshow(Convolution_Max, cmap = 'gray', interpolation = 'bicubic')

# %%
plt.show()

# %%
def bubble_sort_Min(random_list):    
    for start_index in range( len(random_list)-1 ):
        for index in range( 1, len(random_list) - start_index ):
            if random_list[index-1] > random_list[index]:
                temp = random_list[index-1]
                random_list[index-1] = random_list[index]
                random_list[index] = temp
                
    return random_list[0]

# %%
Min  = np.zeros((img.shape[0],img.shape[1],3), 'uint8')

Min_array = np.zeros((3,9), 'uint8')

# %%
for i in range(1,Min.shape[0]-1):
    for j in range(1,Min.shape[1]-1):
        cnt = 0
        for k in range(0,3):
            for l in range(0,3):
                Min_array[0,cnt]=img[i+k-1,j+l-1,0]
                Min_array[1,cnt]=img[i+k-1,j+l-1,1]
                Min_array[2,cnt]=img[i+k-1,j+l-1,2]
                cnt = cnt+1
                      
        Min[i,j,0] = bubble_sort_Min(Min_array[0])
        Min[i,j,1] = bubble_sort_Min(Min_array[1])
        Min[i,j,2] = bubble_sort_Min(Min_array[2])

# %%
plt.imshow(Convolution_Min, cmap = 'gray', interpolation = 'bicubic')

# %%
plt.show()
